# %%
import numpy as np
import pandas as pd

# %%
books=pd.read_csv('Books.csv')
books.head()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_4344\2327456981.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv('Books.csv')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# ...

# %%
ratings=pd.read_csv('Ratings.csv')
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users=pd.read_csv('Users.csv')
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
books.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isna().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isna().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books['Year-Of-Publication'].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
# ...

# %%
valid_years = books['Year-Of-Publication'].astype(str).str.isnumeric()
valid_years
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 271355    True
# 271356    True
# 271357    True
# 271358    True
# 271359    True
# Name: Year-Of-Publication, Length: 271357, dtype: bool

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=books['Year-Of-Publication'])
plt.xticks(rotation=45)
plt.show()

# %%
books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(int)

books['Year-Of-Publication'].min()
# Out:
# 1950

# %%
books['Year-Of-Publication'].value_counts()
# Out:
# Year-Of-Publication
# 2002    17627
# 1999    17431
# 2001    17359
# 2000    17232
# 1998    15766
#         ...
# 2011        2
# 2010        2
# 2021        1
# 2012        1
# 2008        1
# Name: count, Length: 63, dtype: int64

# %%
rearragned_years = (books['Year-Of-Publication']>1949) & (books['Year-Of-Publication']<2023)
books = books[rearragned_years]

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=books['Year-Of-Publication'])
plt.xticks(rotation=90)
plt.show()

# %%
books['Publisher'].value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Publisher'>

# %%
books['Book-Author'].value_counts()
# Out:
# Book-Author
# Agatha Christie        595
# William Shakespeare    558
# Stephen King           511
# Ann M. Martin          423
# Francine Pascal        372
#                       ...
# Leni Fiedelmeier         1
# Jaime J. Sucher          1
# Nancy Searle             1
# Bob Bennett              1
# Christopher  Biffle      1
# Name: count, Length: 100583, dtype: int64

# %%
agatha_christie_books = books[books['Book-Author'] == 'Agatha Christie']
shakespeare_books = books[books['Book-Author'] == 'William Shakespeare']
stephen_king_books = books[books['Book-Author'] == 'Stephen King']

# Group by publisher and count the number of books for each author
agatha_christie_publishers = agatha_christie_books['Publisher'].value_counts()
shakespeare_publishers = shakespeare_books['Publisher'].value_counts()
stephen_king_publishers = stephen_king_books['Publisher'].value_counts()


agatha_christie_publishers
# Out:
# Publisher
# Berkley Publishing Group              102
# Pocket                                 93
# Scherz                                 48
# Librairie des Champs-ElysÃ?Â©es        24
# Harper Mass Market Paperbacks (Mm)     21
#                                      ...
# Simon &amp; Schuster                    1
# Downtown Book Center Inc                1
# Putnam                                  1
# Collins                                 1
# Random House Audio                      1
# Name: count, Length: 90, dtype: int64

# %%
print("Top 5 Publishers for Agatha Christie, William Shakespeare and Stephen King")
print()
print(f"Agatha Christie's top 5 publishers: {agatha_christie_publishers[:5]}")
print()
print(f"William Shakespeare's top 5 publishers: {shakespeare_publishers[:5]}")
print()
print(f"Stephen King's top 5 publishers: {stephen_king_publishers[:5]}")
# Out:
# Top 5 Publishers for Agatha Christie, William Shakespeare and Stephen King
#
# Agatha Christie's top 5 publishers: Publisher
# Berkley Publishing Group              102
# Pocket                                 93
# Scherz                                 48
# Librairie des Champs-ElysÃ?Â©es        24
# Harper Mass Market Paperbacks (Mm)     21
# Name: count, dtype: int64
#
# William Shakespeare's top 5 publishers: Publisher
# Penguin Books              65
# Washington Square Press    62
# Signet Classics            31
# Signet Book                31
# Bantam                     24
# Name: count, dtype: int64
#
# Stephen King's top 5 publishers: Publisher
# Signet Book         77
# Heyne               31
# Viking Books        23
# Pocket              22
# New Amer Library    21
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(ratings['Book-Rating'], bins=5, kde=False, color='skyblue')
plt.title('Distribution of Book Ratings')
plt.xlabel('Book Rating')
plt.ylabel('Count')
plt.show()

# Average rating per book
avg_rating_per_book = ratings.groupby('ISBN')['Book-Rating'].mean()
avg_rating_per_book.hist(bins=30, color='lightcoral')
plt.title('Average Rating per Book')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# %%
avg_rating_per_user = ratings.groupby('User-ID')['Book-Rating'].mean()
avg_rating_per_user.hist(bins=30, color='lightgreen')
plt.title('Average Rating per User')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# %%
books_per_author = books['Book-Author'].value_counts()
books_per_author[:10].plot(kind='bar', color='salmon')
plt.title('Top 10 Authors with Most Books')
plt.xlabel('Author')
plt.ylabel('Number of Books')
plt.show()

# %%
avg_rating_per_author = ratings.merge(books[['ISBN', 'Book-Author']], on='ISBN').groupby('Book-Author')['Book-Rating'].mean()
avg_rating_per_author[:10].plot(kind='bar', color='lightblue')
plt.title('Top 10 Authors with Highest Average Rating')
plt.xlabel('Author')
plt.ylabel('Average Rating')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=books['Year-Of-Publication'])
plt.xticks(rotation=90)
plt.title('Distribution of Books Based on Publication Year')
plt.xlabel('Publication Year')
plt.ylabel('Count')
plt.show()

# %%
avg_rating_per_year = ratings.merge(books[['ISBN', 'Year-Of-Publication']], on='ISBN').groupby('Year-Of-Publication')['Book-Rating'].mean()
avg_rating_per_year.plot(marker='o', linestyle='-', color='orange')
plt.title('Average Rating Based on Publication Year')
plt.xlabel('Publication Year')
plt.ylabel('Average Rating')
plt.show()

# %%
books_per_publisher = books['Publisher'].value_counts()
books_per_publisher[:10].plot(kind='bar', color='lightgreen')
plt.title('Top 10 Publishers with Most Books')
plt.xlabel('Publisher')
plt.ylabel('Number of Books')
plt.show()

# %%
avg_rating_per_publisher = ratings.merge(books[['ISBN', 'Publisher']], on='ISBN').groupby('Publisher')['Book-Rating'].mean()
avg_rating_per_publisher[:10].plot(kind='bar', color='lightpink')
plt.title('Top 10 Publishers with Highest Average Rating')
plt.xlabel('Publisher')
plt.ylabel('Average Rating')
plt.show()

# %%
avg_rating_per_user = ratings.groupby('User-ID')['Book-Rating'].mean()
avg_rating_per_user.hist(bins=20, color='orange')
plt.title('Average Rating per User')
plt.xlabel('Average Rating')
plt.ylabel('Count')
plt.show()

# %%
top_users = ratings['User-ID'].value_counts()[:10]
top_users.plot(kind='bar', color='lightcoral')
plt.title('Top 10 Users with Most Ratings')
plt.xlabel('User ID')
plt.ylabel('Number of Ratings')
plt.show()

# %%
pip install wordcloud
# Out:
# ...
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ------- ------------------------------- 61.4/300.2 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------------  297.0/300.2 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 2.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud

# Generate a word cloud for book titles
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(books['Book-Title']))

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Book Titles')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(users['Age'].dropna(), bins=30, color='lightgreen')
plt.title('Distribution of User Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
merged_data = ratings.merge(books[['ISBN', 'Book-Author', 'Year-Of-Publication', 'Publisher','Book-Title']], on='ISBN')
merged_data = merged_data.merge(users[['User-ID', 'Age']], on='User-ID')
merged_data.head()
# Out:
#    User-ID        ISBN  Book-Rating       Book-Author  Year-Of-Publication  \
# 0   276725  034545104X            0        M. J. Rose                 2002
# 1     2313  034545104X            5        M. J. Rose                 2002
# 2     2313  0812533550            9  Orson Scott Card                 1986
# 3     2313  0679745580            8     TRUMAN CAPOTE                 1994
# 4     2313  0060173289            9     Rebecca Wells                 1996
#
#           Publisher                                        Book-Title   Age
# 0  Ballantine Books                              Flesh Tones: A Novel   NaN
# 1  Ballantine Books                              Flesh Tones: A Novel  23.0
# 2         Tor Books     Ender's Game (Ender Wiggins Saga (Paperback))  23.0
# 3           Vintage             In Cold Blood (Vintage International)  23.0
# 4     HarperCollins  Divine Secrets of the Ya-Ya Sisterhood : A Novel  23.0

# %%
print(f"Duplicates: {merged_data.duplicated().sum()}")
print()
# Check for null values
print(f"Null Values:\n{merged_data.isnull().sum()}")
print()
# Display column names
print(f"Columns: {', '.join(merged_data.columns)}")
print()
# Number of rows in the dataset
print(f"No of Rows {merged_data.shape[0]} and  columns {merged_data.shape[1]} ")
# Out:
# Duplicates: 0
#
# Null Values:
# User-ID                     0
# ISBN                        0
# Book-Rating                 0
# Book-Author                 2
# Year-Of-Publication         0
# Publisher                   2
# Book-Title                  0
# Age                    274067
# dtype: int64
#
# Columns: User-ID, ISBN, Book-Rating, Book-Author, Year-Of-Publication, Publisher, Book-Title, Age
#
# No of Rows 1016338 and  columns 8

# %%
1016338 - 274067
# Out:
# 742271

# %%
final_df=merged_data.dropna()

# %%
final_df
# Out:
#          User-ID        ISBN  Book-Rating                 Book-Author  \
# 1           2313  034545104X            5                  M. J. Rose
# 2           2313  0812533550            9            Orson Scott Card
# 3           2313  0679745580            8               TRUMAN CAPOTE
# 4           2313  0060173289            9               Rebecca Wells
# 5           2313  0385482388            5  Chitra Banerjee Divakaruni
# ...          ...         ...          ...                         ...
# 1016332   276442  2264032960            6                Ellis Peters
# 1016333   276442  2862749796            7           Katherine Neville
# 1016335   276647  0553571001            0            L. M. Montgomery
# 1016336   276647  0689822294           10              Angela Johnson
# 1016337   276660  0583307841            8          David Antony Kroft
#
#          Year-Of-Publication                                   Publisher  \
# ...

# %%
print(f"Duplicates: {final_df.duplicated().sum()}")
print()
# Check for null values
print(f"Null Values:\n{final_df.isnull().sum()}")
print()
# Display column names
print(f"Columns: {', '.join(final_df.columns)}")
print()
# Number of rows in the dataset
print(f"No of Rows {final_df.shape[0]} and  columns {final_df.shape[1]} ")
print()
print(f"Final Dataframe: {final_df.dtypes}")
# Out:
# Duplicates: 0
#
# Null Values:
# User-ID                0
# ISBN                   0
# Book-Rating            0
# Book-Author            0
# Year-Of-Publication    0
# Publisher              0
# Book-Title             0
# Age                    0
# dtype: int64
#
# Columns: User-ID, ISBN, Book-Rating, Book-Author, Year-Of-Publication, Publisher, Book-Title, Age
#
# No of Rows 742267 and  columns 8
#
# Final Dataframe: User-ID                  int64
# ISBN                    object
# Book-Rating              int64
# Book-Author             object
# Year-Of-Publication      int32
# Publisher               object
# Book-Title              object
# Age                    float64
# dtype: object

# %%
age_filtered_df = final_df[(final_df['Age'] >= 10) & (final_df['Age'] <= 60)]

# %%
plt.figure(figsize=(10, 6))
age_filtered_df['Book-Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Book Ratings (Age 10-60)')
plt.xlabel('Book Rating')
plt.ylabel('Number of Ratings')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Book-Rating', data=age_filtered_df)
plt.title('Boxplot of Book Ratings (Age 10-60)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(x='Age', y='Book-Rating', data=age_filtered_df)
plt.title('Violin Plot of Book Ratings by Age')
plt.xlabel('Age')
plt.xticks(rotation=90)


plt.ylabel('Book Rating')
plt.show()

# %%
df=age_filtered_df.copy()

# %%
merged_data=age_filtered_df.copy()

# %%
merged_data
# Out:
#          User-ID        ISBN  Book-Rating                 Book-Author  \
# 1           2313  034545104X            5                  M. J. Rose
# 2           2313  0812533550            9            Orson Scott Card
# 3           2313  0679745580            8               TRUMAN CAPOTE
# 4           2313  0060173289            9               Rebecca Wells
# 5           2313  0385482388            5  Chitra Banerjee Divakaruni
# ...          ...         ...          ...                         ...
# 1016327   276216  9700509222            5                Jack Higgins
# 1016330   276265  0020130902            7       Peter Megargee  Brown
# 1016335   276647  0553571001            0            L. M. Montgomery
# 1016336   276647  0689822294           10              Angela Johnson
# 1016337   276660  0583307841            8          David Antony Kroft
#
#          Year-Of-Publication                                   Publisher  \
# ...

# %%
pip install surprise
# Out:
# ...
#      ---------------------------------------- 0.0/772.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/772.0 kB ? eta -:--:--
#       --------------------------------------- 10.2/772.0 kB ? eta -:--:--
#      - ----------------------------------- 41.0/772.0 kB 393.8 kB/s eta 0:00:02
#      ------------ ------------------------- 245.8/772.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 772.0/772.0 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp311-cp311-win_amd64.whl size=1072821 sha256=b72f0314a452acc69a0ecea23af1cbffc3c122c900db36a6c0750c9f58a86677
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\f4\2b\26\e2a5eae55d3b7688995e66abe7f40473aac6c95ddd8ee174a8
# Successfully built scikit-surprise
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from surprise import Reader, Dataset
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise import accuracy

# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(0, 10))

# Load the data into a Surprise Dataset
data = Dataset.load_from_df(merged_data[['User-ID', 'ISBN', 'Book-Rating']], reader)

# Split the data into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
# Build the collaborative filtering model (SVD algorithm)
model = SVD()

# Train the model on the training set
model.fit(trainset)

# Make predictions on the test set
predictions = model.test(testset)

# Evaluate the model's accuracy
accuracy.rmse(predictions)
# Out:
# RMSE: 3.5104
# 3.51040718330596

# %%
merged_data["User-ID"].unique()
# Out:
# array([  2313,   6543,  23768, ..., 276265, 276647, 276660], dtype=int64)

# %%
# Get top N book recommendations for a specific user
user_id_to_recommend = 2313 
user_items = merged_data[merged_data['User-ID'] == user_id_to_recommend]['ISBN'].tolist()

# Create a list of books that the user hasn't rated
all_books = merged_data['ISBN'].unique()
books_to_recommend = [book for book in all_books if book not in user_items]

# books_to_recommend

# %%
user_ratings = [(user_id_to_recommend, book, model.predict(user_id_to_recommend, book).est) for book in books_to_recommend]
user_ratings
# user_ratings
# Out:
# [(2313, '0316666343', 6.512356049941524),
#  (2313, '0385504209', 6.349978727857933),
#  (2313, '0971880107', 3.028399343302712),
#  (2313, '0312966970', 6.404740556563721),
#  (2313, '0553581112', 5.047613819166277),
#  (2313, '0446605484', 5.432927065208433),
#  (2313, '0446611212', 5.948350380446721),
#  (2313, '0609804138', 4.832713822967819),
#  (2313, '0393319296', 3.9963564813733727),
#  (2313, '0805062971', 6.740365603103464),
#  (2313, '0345342968', 4.564467406796809),
#  (2313, '0446610038', 7.100401556135852),
#  (2313, '0425144690', 4.956972761542533),
#  (2313, '0385483503', 6.214775614839995),
#  (2313, '0671010115', 4.243797152885648),
#  (2313, '0312195516', 7.635757236069026),
#  (2313, '0670894494', 3.987153297183074),
#  (2313, '0061009059', 5.488579402098657),
#  (2313, '0142001740', 6.993266177244286),
#  (2313, '0152050167', 5.4667123791081815),
#  (2313, '0312966091', 4.558517948295644),
#  (2313, '0316168688', 5.016216694384669),
# ...

# %%
# Sort the predictions and get the top N recommendations
top_n_recommendations = sorted(user_ratings, key=lambda x: x[2], reverse=True)[:10]

top_n_recommendations
# Out:
# [(2313, '1844262553', 10),
#  (2313, '0786868716', 9.79199861561578),
#  (2313, '0140143505', 9.534487843661042),
#  (2313, '0446310786', 9.456032825774207),
#  (2313, '0440219078', 9.322289472299856),
#  (2313, '0451167716', 9.128645447000386),
#  (2313, '0671027344', 9.124541825062561),
#  (2313, '0451523377', 9.037356725750014),
#  (2313, '0440183057', 8.99868495931998),
#  (2313, '3423071516', 8.812475080916958)]

# %%
# Display the top N recommendations
recommended_books = [(book_id, merged_data[merged_data['ISBN'] == book_id]['Book-Title'].iloc[0]) for (_, book_id, _) in top_n_recommendations]
print(f"Top 10 Recommendations for User {user_id_to_recommend}:\n")
for idx, (book_id, title) in enumerate(recommended_books, start=1):
    print(f"{idx}. {title} (ISBN: {book_id})")
# Out:
# Top 10 Recommendations for User 2313:
#
# 1. Free (ISBN: 1844262553)
# 2. The Five People You Meet in Heaven (ISBN: 0786868716)
# 3. 84 Charing Cross Road (ISBN: 0140143505)
# 4. To Kill a Mockingbird (ISBN: 0446310786)
# 5. The Giver (21st Century Reference) (ISBN: 0440219078)
# 6. The Godfather (ISBN: 0451167716)
# 7. The Perks of Being a Wallflower (ISBN: 0671027344)
# 8. Dracula (Signet Classics (Paperback)) (ISBN: 0451523377)
# 9. Stillwatch (ISBN: 0440183057)
# 10. Der Kleine Hobbit (ISBN: 3423071516)

# %%
# Printing books read by user 2313
user_id_to_print = 2313  

books_read_by_user = merged_data[merged_data['User-ID'] == user_id_to_print][['ISBN', 'Book-Title']]

print(f"Books read by User {user_id_to_print}:\n")
for idx, (isbn, title) in enumerate(zip(books_read_by_user['ISBN'], books_read_by_user['Book-Title']), start=1):
    print(f"{idx}. {title} (ISBN: {isbn})")
# Out:
# Books read by User 2313:
#
# 1. Flesh Tones: A Novel (ISBN: 034545104X)
# 2. Ender's Game (Ender Wiggins Saga (Paperback)) (ISBN: 0812533550)
# 3. In Cold Blood (Vintage International) (ISBN: 0679745580)
# 4. Divine Secrets of the Ya-Ya Sisterhood : A Novel (ISBN: 0060173289)
# 5. The Mistress of Spices (ISBN: 0385482388)
# 6. The Bonesetter's Daughter (ISBN: 0399146431)
# 7. The Princess Bride: S Morgenstern's Classic Tale of True Love and High Adventure (ISBN: 0345348036)
# 8. The Martian Chronicles (ISBN: 0553278223)
# 9. The Sparrow (ISBN: 0449912558)
# 10. Voyage of the Dawn Treader (ISBN: 0020442602)
# 11. No-No Boy (ISBN: 0295955252)
# 12. Cosima Wagner's Diaries: An Abridgement (ISBN: 0300069049)
# 13. An Arrow's Flight (ISBN: 0312186754)
# 14. The Path of Minor Planets : A Novel (ISBN: 0312275560)
# 15. Shadow of the Hegemon (Ender Wiggins Saga (Hardcover)) (ISBN: 0312876513)
# 16. Midwives: A Novel (ISBN: 0375706771)
# ...

# %%
from surprise.dump import dump

# Save the trained model to a file
model_filename = 'svd_model'
dump(model_filename, algo=model)

print(f"Model saved to {model_filename}")
# Out:
# Model saved to svd_model
